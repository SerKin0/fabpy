# %%
# %pip install numpy matplotlib scikit-learn pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
path_url = r"https://github.com/RFUNN/Lab/blob/main/student_data.csv"
data = pd.read_csv()
