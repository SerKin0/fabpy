# %%
from fabpy import Values

# %%
_U_out = [0.360, 0.352, 0.356, 0.348, 0.352, 0.352, 0.352, 0.352, 0.344, 0.344, 0.336, 0.308, 0.288, 0.272, 0.254, 0.240]

list_U_out = []

for index, u in enumerate(_U_out):
    U_out = Values(
        name=fr'2U_\text{{вых\,{index}}}',
        values=u,
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 list_U_out = []
#       5 for index, u in enumerate(_U_out):
# ----> 6     U_out = Values(
#       7         name=fr'2U_\text{{вых\,{index}}}',
#       8         values=u,
#       9         )
#
# NameError: name 'Values' is not defined

# %%
from fabpy import Values

data_t = [10.5, 10.7, 10.6]

# Создание переменной времени с соответсующими данными
t = Values(name='t', values=data_t, unit=r'с', delta=0.1)

# %%
from sympy.abc import a, b, c
from sympy import diff

f = 4 * a**2
r = diff(f, a)
r * t
print(type(r), type(t))
# Out:
# <class 'sympy.core.mul.Mul'> <class 'fabpy.dataclass.Values'>
